# %%
a = 3
b = 9
from random import shuffle
import numpy as np

# %%
b +=a

# %%
b
# Out:
# 12

# %%
dataset_f = "heart.csv"

# %%
x = []
data = open(dataset_f, 'r')
for buff in data:
    x.append(buff.strip().split(","))

# %%
x.pop(0)
data = []
for buff in x:
    data.append([float(a) for a in buff])

# %%
shuffle(data)

# %%
len(data[1])
# Out:
# 14

# %%
x = []
y = []

# %%
for buff in data:
    y.append(buff.pop())
    x.append(buff)

# %%
x
# Out:
# [[76.0, 0.0, 2.0, 140.0, 197.0, 0.0, 2.0, 116.0, 0.0, 1.1, 1.0, 0.0, 2.0],
#  [65.0, 0.0, 2.0, 160.0, 360.0, 0.0, 0.0, 151.0, 0.0, 0.8, 2.0, 0.0, 2.0],
#  [55.0, 1.0, 0.0, 132.0, 353.0, 0.0, 1.0, 132.0, 1.0, 1.2, 1.0, 1.0, 3.0],
#  [34.0, 0.0, 1.0, 118.0, 210.0, 0.0, 1.0, 192.0, 0.0, 0.7, 2.0, 0.0, 2.0],
#  [58.0, 1.0, 0.0, 114.0, 318.0, 0.0, 2.0, 140.0, 0.0, 4.4, 0.0, 3.0, 1.0],
#  [49.0, 1.0, 2.0, 118.0, 149.0, 0.0, 0.0, 126.0, 0.0, 0.8, 2.0, 3.0, 2.0],
#  [51.0, 1.0, 0.0, 140.0, 298.0, 0.0, 1.0, 122.0, 1.0, 4.2, 1.0, 3.0, 3.0],
#  [63.0, 0.0, 0.0, 150.0, 407.0, 0.0, 0.0, 154.0, 0.0, 4.0, 1.0, 3.0, 3.0],
#  [42.0, 1.0, 1.0, 120.0, 295.0, 0.0, 1.0, 162.0, 0.0, 0.0, 2.0, 0.0, 2.0],
#  [64.0, 1.0, 3.0, 110.0, 211.0, 0.0, 0.0, 144.0, 1.0, 1.8, 1.0, 0.0, 2.0],
#  [42.0, 1.0, 2.0, 130.0, 180.0, 0.0, 1.0, 150.0, 0.0, 0.0, 2.0, 0.0, 2.0],
#  [65.0, 1.0, 3.0, 138.0, 282.0, 1.0, 0.0, 174.0, 0.0, 1.4, 1.0, 1.0, 2.0],
# ...

# %%
a = [1,2,3,4,5,6,7,8,9,0]

# %%
a[:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
a[5:]
# Out:
# [6, 7, 8, 9, 0]

# %%
x_train = x[:280]
x_test = x[280:]
y_train = y[:280]
y_test = y[280:]

# %%
heart = {
    'x_train' = x_train.

# %%
a = np.random.randn(784, 10)
c = np.random.randn(784)

# %%
(c * 10).shape
# Out:
# (784,)

# %%
arrays = [np.random.randn(3, 4) for _ in range(10)]

# %%
arrays
# Out:
# [array([[ 0.52563286,  1.17700574, -0.02823173,  0.06921129],
#         [ 1.29632138,  0.99592056,  0.39443177,  0.16600118],
#         [-0.54065196,  1.03159134,  2.03684793, -2.64087786]]),
#  array([[ 0.44464415, -1.1750166 ,  1.36025502,  0.1848849 ],
#         [-1.00198999,  0.72369661,  0.69726601,  0.74635583],
#         [ 1.15370215,  1.12217342,  1.13277876, -1.0098005 ]]),
#  array([[ 0.05840216, -1.13451036, -1.63975894, -0.20538082],
#         [ 0.12134087, -1.35821087, -1.21390794, -0.73471366],
#         [ 0.01655573,  1.51976364, -1.68459019, -0.45397611]]),
#  array([[ 1.33945527, -1.02732719,  1.06262388,  1.18021545],
#         [ 0.15159085, -0.48801366,  0.37306117,  1.0072436 ],
#         [-2.00031693, -0.03709808,  1.12832973,  1.8921432 ]]),
#  array([[-0.70339992,  0.6962557 , -1.20409082, -0.39906209],
#         [-0.12394081,  0.72877944,  1.07444424,  1.18160218],
#         [ 0.05122947,  0.97085808,  1.10167621, -1.25432268]]),
# ...
